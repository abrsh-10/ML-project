# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data  = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
x = data.drop(["median_house_value"],axis = 1)
y = data["median_house_value"]

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3137     -117.65     35.00                36.0       1184.0           316.0
# 6236     -117.96     34.06                34.0       2226.0           381.0
# 8151     -118.10     33.81                36.0       1111.0           184.0
# 3190     -119.80     36.29                 7.0        479.0            84.0
# 15315    -117.38     33.20                26.0       1427.0           386.0
# ...          ...       ...                 ...          ...             ...
# 13517    -117.34     34.10                14.0      11827.0          2445.0
# 11520    -118.06     33.72                14.0       2665.0           331.0
# 7165     -118.17     34.05                35.0       1256.0           294.0
# 3635     -118.43     34.23                37.0       1737.0           369.0
# 2622     -124.10     40.95                17.0       1485.0           345.0
#
#        population  households  median_income ocean_proximity
# 3137        672.0       241.0         1.9107          INLAND
# 6236       1464.0       365.0         4.4102       <1H OCEAN
# 8151        444.0       177.0         3.7031       <1H OCEAN
# 3190        327.0       103.0         5.1728          INLAND
# 15315       974.0       317.0         1.3903      NEAR OCEAN
# ...           ...         ...            ...             ...
# 13517      6640.0      2299.0         2.4878          INLAND
# 11520       964.0       319.0        15.0001      NEAR OCEAN
# 7165       2990.0       302.0         3.1528       <1H OCEAN
# 3635       1061.0       356.0         3.9615       <1H OCEAN
# 2622        823.0       316.0         1.8993      NEAR OCEAN
#
# [16346 rows x 9 columns]

# %%
y_train
# Out:
# 3137      39800.0
# 6236     183200.0
# 8151     245300.0
# 3190     107500.0
# 15315    184400.0
#            ...
# 13517    103800.0
# 11520    500001.0
# 7165     121800.0
# 3635     173700.0
# 2622      78400.0
# Name: median_house_value, Length: 16346, dtype: float64

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11669    -118.01     33.86                29.0       2307.0           452.0
# 2171     -119.87     36.78                 4.0       6102.0          1114.0
# 5761     -118.29     34.18                10.0       4292.0          1075.0
# 12974    -121.33     38.67                17.0       2683.0           704.0
# 7542     -118.21     33.90                35.0       2420.0           579.0
# ...          ...       ...                 ...          ...             ...
# 399      -122.29     37.89                52.0       2269.0           380.0
# 16225    -121.33     37.97                38.0       3166.0           575.0
# 4567     -118.26     34.06                38.0        715.0           282.0
# 3141     -118.17     34.86                21.0       2370.0           540.0
# 9427     -122.84     38.07                31.0       1858.0           367.0
#
#        population  households  median_income ocean_proximity
# 11669      1218.0       402.0         3.4306       <1H OCEAN
# 2171       3406.0      1115.0         3.4213          INLAND
# 5761       2719.0       987.0         3.6974       <1H OCEAN
# 12974      1410.0       659.0         1.9620          INLAND
# 7542       2010.0       540.0         2.0817       <1H OCEAN
# ...           ...         ...            ...             ...
# 399        1004.0       371.0         5.1696        NEAR BAY
# 16225      1351.0       561.0         3.5404          INLAND
# 4567       1174.0       300.0         2.3450       <1H OCEAN
# 3141       1488.0       554.0         2.7361          INLAND
# 9427        701.0       297.0         3.8269      NEAR OCEAN
#
# [4087 rows x 9 columns]

# %%
train_data = x_train.join(y_train)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16346 entries, 3137 to 2622
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16346 non-null  float64
#  1   latitude            16346 non-null  float64
#  2   housing_median_age  16346 non-null  float64
#  3   total_rooms         16346 non-null  float64
#  4   total_bedrooms      16346 non-null  float64
#  5   population          16346 non-null  float64
#  6   households          16346 non-null  float64
#  7   median_income       16346 non-null  float64
#  8   ocean_proximity     16346 non-null  object
#  9   median_house_value  16346 non-null  float64
# dtypes: float64(9), object(1)
# memory usage: 1.9+ MB

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.corr(), annot = True,cmap = "YlGnBu")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 plt.figure(figsize = (15,8))
# ----> 2 sns.heatmap(train_data.corr(), annot = True,cmap = "YlGnBu")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'INLAND'

# %%
train_data.drop(["ocean_proximity"],axis = 1).corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924219           -0.108793     0.049538
# latitude            -0.924219  1.000000            0.011355    -0.040460
# housing_median_age  -0.108793  0.011355            1.000000    -0.364114
# total_rooms          0.049538 -0.040460           -0.364114     1.000000
# total_bedrooms       0.072096 -0.069418           -0.324100     0.932517
# population           0.101408 -0.111264           -0.297048     0.855192
# households           0.058371 -0.074337           -0.306539     0.920195
# median_income       -0.015556 -0.080112           -0.118609     0.197945
# median_house_value  -0.046350 -0.144689            0.102060     0.134191
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.072096    0.101408    0.058371      -0.015556
# latitude                 -0.069418   -0.111264   -0.074337      -0.080112
# housing_median_age       -0.324100   -0.297048   -0.306539      -0.118609
# total_rooms               0.932517    0.855192    0.920195       0.197945
# total_bedrooms            1.000000    0.875058    0.978761      -0.005443
# population                0.875058    1.000000    0.905465       0.007537
# households                0.978761    0.905465    1.000000       0.016197
# median_income            -0.005443    0.007537    0.016197       1.000000
# median_house_value        0.049810   -0.023655    0.066595       0.691862
#
#                     median_house_value
# longitude                    -0.046350
# latitude                     -0.144689
# housing_median_age            0.102060
# total_rooms                   0.134191
# total_bedrooms                0.049810
# population                   -0.023655
# households                    0.066595
# median_income                 0.691862
# median_house_value            1.000000

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.drop(["ocean_proximity"],axis = 1).corr(),annot = True,cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
train_data["total_rooms"] = np.log(train_data["total_rooms"] +1)

# %%
train_data["total_bedrooms"] = np.log(train_data["total_bedrooms"] +1)

# %%
train_data["population"] = np.log(train_data["population"] +1)

# %%
train_data["households"] = np.log(train_data["households"] +1)

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     7218
# INLAND        5194
# NEAR OCEAN    2096
# NEAR BAY      1833
# ISLAND           5
# Name: count, dtype: int64

# %%
o = pd.get_dummies(train_data.ocean_proximity)

# %%
train_data.join(o)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3137     -117.65     35.00                36.0     7.077498        5.758902
# 6236     -117.96     34.06                34.0     7.708411        5.945421
# 8151     -118.10     33.81                36.0     7.013915        5.220356
# 3190     -119.80     36.29                 7.0     6.173786        4.442651
# 15315    -117.38     33.20                26.0     7.264030        5.958425
# ...          ...       ...                 ...          ...             ...
# 13517    -117.34     34.10                14.0     9.378225        7.802209
# 11520    -118.06     33.72                14.0     7.888335        5.805135
# 7165     -118.17     34.05                35.0     7.136483        5.686975
# 3635     -118.43     34.23                37.0     7.460490        5.913503
# 2622     -124.10     40.95                17.0     7.303843        5.846439
#
#        population  households  median_income ocean_proximity  \
# 3137     6.511745    5.488938         1.9107          INLAND
# 6236     7.289611    5.902633         4.4102       <1H OCEAN
# 8151     6.098074    5.181784         3.7031       <1H OCEAN
# 3190     5.793014    4.644391         5.1728          INLAND
# 15315    6.882437    5.762051         1.3903      NEAR OCEAN
# ...           ...         ...            ...             ...
# 13517    8.801018    7.740664         2.4878          INLAND
# 11520    6.872128    5.768321        15.0001      NEAR OCEAN
# 7165     8.003363    5.713733         3.1528       <1H OCEAN
# 3635     6.967909    5.877736         3.9615       <1H OCEAN
# 2622     6.714171    5.758902         1.8993      NEAR OCEAN
#
#        median_house_value  <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 3137              39800.0      False    True   False     False       False
# 6236             183200.0       True   False   False     False       False
# 8151             245300.0       True   False   False     False       False
# 3190             107500.0      False    True   False     False       False
# 15315            184400.0      False   False   False     False        True
# ...                   ...        ...     ...     ...       ...         ...
# 13517            103800.0      False    True   False     False       False
# 11520            500001.0      False   False   False     False        True
# 7165             121800.0       True   False   False     False       False
# 3635             173700.0       True   False   False     False       False
# 2622              78400.0      False   False   False     False        True
#
# [16346 rows x 15 columns]

# %%
train_data = train_data.join(o)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3137     -117.65     35.00                36.0     7.077498        5.758902
# 6236     -117.96     34.06                34.0     7.708411        5.945421
# 8151     -118.10     33.81                36.0     7.013915        5.220356
# 3190     -119.80     36.29                 7.0     6.173786        4.442651
# 15315    -117.38     33.20                26.0     7.264030        5.958425
# ...          ...       ...                 ...          ...             ...
# 13517    -117.34     34.10                14.0     9.378225        7.802209
# 11520    -118.06     33.72                14.0     7.888335        5.805135
# 7165     -118.17     34.05                35.0     7.136483        5.686975
# 3635     -118.43     34.23                37.0     7.460490        5.913503
# 2622     -124.10     40.95                17.0     7.303843        5.846439
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 3137     6.511745    5.488938         1.9107             39800.0      False
# 6236     7.289611    5.902633         4.4102            183200.0       True
# 8151     6.098074    5.181784         3.7031            245300.0       True
# 3190     5.793014    4.644391         5.1728            107500.0      False
# 15315    6.882437    5.762051         1.3903            184400.0      False
# ...           ...         ...            ...                 ...        ...
# 13517    8.801018    7.740664         2.4878            103800.0      False
# 11520    6.872128    5.768321        15.0001            500001.0      False
# 7165     8.003363    5.713733         3.1528            121800.0       True
# 3635     6.967909    5.877736         3.9615            173700.0       True
# 2622     6.714171    5.758902         1.8993             78400.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 3137     True   False     False       False
# 6236    False   False     False       False
# 8151    False   False     False       False
# 3190     True   False     False       False
# 15315   False   False     False        True
# ...       ...     ...       ...         ...
# 13517    True   False     False       False
# 11520   False   False     False        True
# 7165    False   False     False       False
# 3635    False   False     False       False
# 2622    False   False     False        True
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.corr(),annot = True,cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
plt.figure(figsize = (15,8))
sns.scatterplot(x="latitude" , y="longitude" , data=train_data , hue="median_house_value" , palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data["bedroom_ratio"] = train_data["total_bedrooms"] / train_data["total_rooms"]

# %%
train_data["household_room"] = train_data["total_rooms"] / train_data["households"]

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.corr(),annot = True,cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
x_train , y_train = train_data.drop(["median_house_value"],axis = 1),train_data["median_house_value"]

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data = x_test.join(y_test)

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11669    -118.01     33.86                29.0       2307.0           452.0
# 2171     -119.87     36.78                 4.0       6102.0          1114.0
# 5761     -118.29     34.18                10.0       4292.0          1075.0
# 12974    -121.33     38.67                17.0       2683.0           704.0
# 7542     -118.21     33.90                35.0       2420.0           579.0
# ...          ...       ...                 ...          ...             ...
# 399      -122.29     37.89                52.0       2269.0           380.0
# 16225    -121.33     37.97                38.0       3166.0           575.0
# 4567     -118.26     34.06                38.0        715.0           282.0
# 3141     -118.17     34.86                21.0       2370.0           540.0
# 9427     -122.84     38.07                31.0       1858.0           367.0
#
#        population  households  median_income ocean_proximity  \
# 11669      1218.0       402.0         3.4306       <1H OCEAN
# 2171       3406.0      1115.0         3.4213          INLAND
# 5761       2719.0       987.0         3.6974       <1H OCEAN
# 12974      1410.0       659.0         1.9620          INLAND
# 7542       2010.0       540.0         2.0817       <1H OCEAN
# ...           ...         ...            ...             ...
# 399        1004.0       371.0         5.1696        NEAR BAY
# 16225      1351.0       561.0         3.5404          INLAND
# 4567       1174.0       300.0         2.3450       <1H OCEAN
# 3141       1488.0       554.0         2.7361          INLAND
# 9427        701.0       297.0         3.8269      NEAR OCEAN
#
#        median_house_value
# 11669            194200.0
# 2171              84500.0
# 5761             286600.0
# 12974            130200.0
# 7542             104600.0
# ...                   ...
# 399              261400.0
# 16225             91600.0
# 4567             225000.0
# 3141              83300.0
# 9427             270700.0
#
# [4087 rows x 10 columns]

# %%
test_data["total_rooms"] = np.log(test_data["total_rooms"] +1)
test_data["total_bedrooms"] = np.log(test_data["total_bedrooms"] +1)
test_data["population"] = np.log(test_data["population"] +1)
test_data["households"] = np.log(test_data["households"] +1)

test_data = test_data.join(pd.get_dummies(test_data["ocean_proximity"])).drop(["ocean_proximity"],axis = 1)

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11669    -118.01     33.86                29.0     7.744137        6.115892
# 2171     -119.87     36.78                 4.0     8.716536        7.016610
# 5761     -118.29     34.18                10.0     8.364741        6.981006
# 12974    -121.33     38.67                17.0     7.895063        6.558198
# 7542     -118.21     33.90                35.0     7.791936        6.363028
# ...          ...       ...                 ...          ...             ...
# 399      -122.29     37.89                52.0     7.727535        5.942799
# 16225    -121.33     37.97                38.0     8.060540        6.356108
# 4567     -118.26     34.06                38.0     6.573680        5.645447
# 3141     -118.17     34.86                21.0     7.771067        6.293419
# 9427     -122.84     38.07                31.0     7.527794        5.908083
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 11669    7.105786    5.998937         3.4306            194200.0       True
# 2171     8.133587    7.017506         3.4213             84500.0      False
# 5761     7.908387    6.895683         3.6974            286600.0       True
# 12974    7.252054    6.492240         1.9620            130200.0      False
# 7542     7.606387    6.293419         2.0817            104600.0       True
# ...           ...         ...            ...                 ...        ...
# 399      6.912743    5.918894         5.1696            261400.0      False
# 16225    7.209340    6.331502         3.5404             91600.0      False
# 4567     7.069023    5.707110         2.3450            225000.0       True
# 3141     7.305860    6.318968         2.7361             83300.0      False
# 9427     6.553933    5.697093         3.8269            270700.0      False
#
#        INLAND  NEAR BAY  NEAR OCEAN
# 11669   False     False       False
# 2171     True     False       False
# 5761    False     False       False
# 12974    True     False       False
# 7542    False     False       False
# ...       ...       ...         ...
# 399     False      True       False
# 16225    True     False       False
# 4567    False     False       False
# 3141     True     False       False
# 9427    False     False        True
#
# [4087 rows x 13 columns]

# %%
test_data["bedroom_ratio"] = test_data["total_bedrooms"] / test_data["total_rooms"]
test_data["household_room"] = test_data["total_rooms"] / test_data["households"]

# %%
reg.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 reg.score(x_test,y_test)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:760, in RegressorMixin.score(self, X, y, sample_weight)
#     718 """Return the coefficient of determination of the prediction.
#     719
#     720 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     755 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     756 """
#     758 from .metrics import r2_score
# --> 760 y_pred = self.predict(X)
#     761 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
#     367     check_is_fitted(self)
# --> 369     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:580, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     509 def _validate_data(
#     510     self,
#     511     X="no_validation",
#    (...)
#     516     **check_params,
#     517 ):
#     518     """Validate input data and set or check the `n_features_in_` attribute.
#     519
#     520     Parameters
#    (...)
#     578         validated.
#     579     """
# --> 580     self._check_feature_names(X, reset=reset)
#     582     if y is None and self._get_tags()["requires_y"]:
#     583         raise ValueError(
#     584             f"This {self.__class__.__name__} estimator "
#     585             "requires y to be passed, but the target y is None."
#     586         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:507, in BaseEstimator._check_feature_names(self, X, reset)
#     502 if not missing_names and not unexpected_names:
#     503     message += (
#     504         "Feature names must be in the same order as they were in fit.\n"
#     505     )
# --> 507 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - household_rooms
# Feature names seen at fit time, yet now missing:
# - ISLAND
# - household_room

# %%
x_test , y_test = test_data.drop(["median_house_value"],axis = 1),test_data["median_house_value"]

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11669    -118.01     33.86                29.0     7.744137        6.115892
# 2171     -119.87     36.78                 4.0     8.716536        7.016610
# 5761     -118.29     34.18                10.0     8.364741        6.981006
# 12974    -121.33     38.67                17.0     7.895063        6.558198
# 7542     -118.21     33.90                35.0     7.791936        6.363028
# ...          ...       ...                 ...          ...             ...
# 399      -122.29     37.89                52.0     7.727535        5.942799
# 16225    -121.33     37.97                38.0     8.060540        6.356108
# 4567     -118.26     34.06                38.0     6.573680        5.645447
# 3141     -118.17     34.86                21.0     7.771067        6.293419
# 9427     -122.84     38.07                31.0     7.527794        5.908083
#
#        population  households  median_income  <1H OCEAN  INLAND  NEAR BAY  \
# 11669    7.105786    5.998937         3.4306       True   False     False
# 2171     8.133587    7.017506         3.4213      False    True     False
# 5761     7.908387    6.895683         3.6974       True   False     False
# 12974    7.252054    6.492240         1.9620      False    True     False
# 7542     7.606387    6.293419         2.0817       True   False     False
# ...           ...         ...            ...        ...     ...       ...
# 399      6.912743    5.918894         5.1696      False   False      True
# 16225    7.209340    6.331502         3.5404      False    True     False
# 4567     7.069023    5.707110         2.3450       True   False     False
# 3141     7.305860    6.318968         2.7361      False    True     False
# 9427     6.553933    5.697093         3.8269      False   False     False
#
#        NEAR OCEAN  bedroom_ratio  household_rooms
# 11669       False       0.789745         1.290918
# 2171        False       0.804977         1.242113
# 5761        False       0.834575         1.213040
# 12974       False       0.830671         1.216077
# 7542        False       0.816617         1.238109
# ...           ...            ...              ...
# 399         False       0.769042         1.305571
# 16225       False       0.788546         1.273085
# 4567        False       0.858795         1.151840
# 3141        False       0.809853         1.229800
# 9427         True       0.784836         1.321339
#
# [4087 rows x 14 columns]

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3137     -117.65     35.00                36.0     7.077498        5.758902
# 6236     -117.96     34.06                34.0     7.708411        5.945421
# 8151     -118.10     33.81                36.0     7.013915        5.220356
# 3190     -119.80     36.29                 7.0     6.173786        4.442651
# 15315    -117.38     33.20                26.0     7.264030        5.958425
# ...          ...       ...                 ...          ...             ...
# 13517    -117.34     34.10                14.0     9.378225        7.802209
# 11520    -118.06     33.72                14.0     7.888335        5.805135
# 7165     -118.17     34.05                35.0     7.136483        5.686975
# 3635     -118.43     34.23                37.0     7.460490        5.913503
# 2622     -124.10     40.95                17.0     7.303843        5.846439
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 3137     6.511745    5.488938         1.9107      False    True   False
# 6236     7.289611    5.902633         4.4102       True   False   False
# 8151     6.098074    5.181784         3.7031       True   False   False
# 3190     5.793014    4.644391         5.1728      False    True   False
# 15315    6.882437    5.762051         1.3903      False   False   False
# ...           ...         ...            ...        ...     ...     ...
# 13517    8.801018    7.740664         2.4878      False    True   False
# 11520    6.872128    5.768321        15.0001      False   False   False
# 7165     8.003363    5.713733         3.1528       True   False   False
# 3635     6.967909    5.877736         3.9615       True   False   False
# 2622     6.714171    5.758902         1.8993      False   False   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_room
# 3137      False       False       0.813692        1.289411
# 6236      False       False       0.771290        1.305927
# 8151      False       False       0.744286        1.353572
# 3190      False       False       0.719599        1.329299
# 15315     False        True       0.820264        1.260667
# ...         ...         ...            ...             ...
# 13517     False       False       0.831949        1.211553
# 11520     False        True       0.735914        1.367527
# 7165      False       False       0.796888        1.249005
# 3635      False       False       0.792643        1.269280
# 2622      False        True       0.800461        1.268270
#
# [16346 rows x 15 columns]

# %%
y_test
# Out:
# 11669    194200.0
# 2171      84500.0
# 5761     286600.0
# 12974    130200.0
# 7542     104600.0
#            ...
# 399      261400.0
# 16225     91600.0
# 4567     225000.0
# 3141      83300.0
# 9427     270700.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
y_test
# Out:
# 11669    194200.0
# 2171      84500.0
# 5761     286600.0
# 12974    130200.0
# 7542     104600.0
#            ...
# 399      261400.0
# 16225     91600.0
# 4567     225000.0
# 3141      83300.0
# 9427     270700.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3137     -117.65     35.00                36.0     7.077498        5.758902
# 6236     -117.96     34.06                34.0     7.708411        5.945421
# 8151     -118.10     33.81                36.0     7.013915        5.220356
# 3190     -119.80     36.29                 7.0     6.173786        4.442651
# 15315    -117.38     33.20                26.0     7.264030        5.958425
# ...          ...       ...                 ...          ...             ...
# 13517    -117.34     34.10                14.0     9.378225        7.802209
# 11520    -118.06     33.72                14.0     7.888335        5.805135
# 7165     -118.17     34.05                35.0     7.136483        5.686975
# 3635     -118.43     34.23                37.0     7.460490        5.913503
# 2622     -124.10     40.95                17.0     7.303843        5.846439
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 3137     6.511745    5.488938         1.9107             39800.0      False
# 6236     7.289611    5.902633         4.4102            183200.0       True
# 8151     6.098074    5.181784         3.7031            245300.0       True
# 3190     5.793014    4.644391         5.1728            107500.0      False
# 15315    6.882437    5.762051         1.3903            184400.0      False
# ...           ...         ...            ...                 ...        ...
# 13517    8.801018    7.740664         2.4878            103800.0      False
# 11520    6.872128    5.768321        15.0001            500001.0      False
# 7165     8.003363    5.713733         3.1528            121800.0       True
# 3635     6.967909    5.877736         3.9615            173700.0       True
# 2622     6.714171    5.758902         1.8993             78400.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_room
# 3137     True   False     False       False       0.813692        1.289411
# 6236    False   False     False       False       0.771290        1.305927
# 8151    False   False     False       False       0.744286        1.353572
# 3190     True   False     False       False       0.719599        1.329299
# 15315   False   False     False        True       0.820264        1.260667
# ...       ...     ...       ...         ...            ...             ...
# 13517    True   False     False       False       0.831949        1.211553
# 11520   False   False     False        True       0.735914        1.367527
# 7165    False   False     False       False       0.796888        1.249005
# 3635    False   False     False       False       0.792643        1.269280
# 2622    False   False     False        True       0.800461        1.268270
#
# [16346 rows x 16 columns]

# %%
x_train , y_train = train_data.drop(["median_house_value"],axis = 1),train_data["median_house_value"]

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3137     -117.65     35.00                36.0     7.077498        5.758902
# 6236     -117.96     34.06                34.0     7.708411        5.945421
# 8151     -118.10     33.81                36.0     7.013915        5.220356
# 3190     -119.80     36.29                 7.0     6.173786        4.442651
# 15315    -117.38     33.20                26.0     7.264030        5.958425
# ...          ...       ...                 ...          ...             ...
# 13517    -117.34     34.10                14.0     9.378225        7.802209
# 11520    -118.06     33.72                14.0     7.888335        5.805135
# 7165     -118.17     34.05                35.0     7.136483        5.686975
# 3635     -118.43     34.23                37.0     7.460490        5.913503
# 2622     -124.10     40.95                17.0     7.303843        5.846439
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 3137     6.511745    5.488938         1.9107      False    True   False
# 6236     7.289611    5.902633         4.4102       True   False   False
# 8151     6.098074    5.181784         3.7031       True   False   False
# 3190     5.793014    4.644391         5.1728      False    True   False
# 15315    6.882437    5.762051         1.3903      False   False   False
# ...           ...         ...            ...        ...     ...     ...
# 13517    8.801018    7.740664         2.4878      False    True   False
# 11520    6.872128    5.768321        15.0001      False   False   False
# 7165     8.003363    5.713733         3.1528       True   False   False
# 3635     6.967909    5.877736         3.9615       True   False   False
# 2622     6.714171    5.758902         1.8993      False   False   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_room
# 3137      False       False       0.813692        1.289411
# 6236      False       False       0.771290        1.305927
# 8151      False       False       0.744286        1.353572
# 3190      False       False       0.719599        1.329299
# 15315     False        True       0.820264        1.260667
# ...         ...         ...            ...             ...
# 13517     False       False       0.831949        1.211553
# 11520     False        True       0.735914        1.367527
# 7165      False       False       0.796888        1.249005
# 3635      False       False       0.792643        1.269280
# 2622      False        True       0.800461        1.268270
#
# [16346 rows x 15 columns]

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 reg.score(x_test,y_test)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:760, in RegressorMixin.score(self, X, y, sample_weight)
#     718 """Return the coefficient of determination of the prediction.
#     719
#     720 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     755 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     756 """
#     758 from .metrics import r2_score
# --> 760 y_pred = self.predict(X)
#     761 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
#     367     check_is_fitted(self)
# --> 369     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:580, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     509 def _validate_data(
#     510     self,
#     511     X="no_validation",
#    (...)
#     516     **check_params,
#     517 ):
#     518     """Validate input data and set or check the `n_features_in_` attribute.
#     519
#     520     Parameters
#    (...)
#     578         validated.
#     579     """
# --> 580     self._check_feature_names(X, reset=reset)
#     582     if y is None and self._get_tags()["requires_y"]:
#     583         raise ValueError(
#     584             f"This {self.__class__.__name__} estimator "
#     585             "requires y to be passed, but the target y is None."
#     586         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:507, in BaseEstimator._check_feature_names(self, X, reset)
#     502 if not missing_names and not unexpected_names:
#     503     message += (
#     504         "Feature names must be in the same order as they were in fit.\n"
#     505     )
# --> 507 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - household_rooms
# Feature names seen at fit time, yet now missing:
# - ISLAND
# - household_room

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11669    -118.01     33.86                29.0     7.744137        6.115892
# 2171     -119.87     36.78                 4.0     8.716536        7.016610
# 5761     -118.29     34.18                10.0     8.364741        6.981006
# 12974    -121.33     38.67                17.0     7.895063        6.558198
# 7542     -118.21     33.90                35.0     7.791936        6.363028
# ...          ...       ...                 ...          ...             ...
# 399      -122.29     37.89                52.0     7.727535        5.942799
# 16225    -121.33     37.97                38.0     8.060540        6.356108
# 4567     -118.26     34.06                38.0     6.573680        5.645447
# 3141     -118.17     34.86                21.0     7.771067        6.293419
# 9427     -122.84     38.07                31.0     7.527794        5.908083
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 11669    7.105786    5.998937         3.4306            194200.0       True
# 2171     8.133587    7.017506         3.4213             84500.0      False
# 5761     7.908387    6.895683         3.6974            286600.0       True
# 12974    7.252054    6.492240         1.9620            130200.0      False
# 7542     7.606387    6.293419         2.0817            104600.0       True
# ...           ...         ...            ...                 ...        ...
# 399      6.912743    5.918894         5.1696            261400.0      False
# 16225    7.209340    6.331502         3.5404             91600.0      False
# 4567     7.069023    5.707110         2.3450            225000.0       True
# 3141     7.305860    6.318968         2.7361             83300.0      False
# 9427     6.553933    5.697093         3.8269            270700.0      False
#
#        INLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms  \
# 11669   False     False       False       0.789745         1.290918
# 2171     True     False       False       0.804977         1.242113
# 5761    False     False       False       0.834575         1.213040
# 12974    True     False       False       0.830671         1.216077
# 7542    False     False       False       0.816617         1.238109
# ...       ...       ...         ...            ...              ...
# 399     False      True       False       0.769042         1.305571
# 16225    True     False       False       0.788546         1.273085
# 4567    False     False       False       0.858795         1.151840
# 3141     True     False       False       0.809853         1.229800
# 9427    False     False        True       0.784836         1.321339
#
#        household_room
# 11669        1.290918
# 2171         1.242113
# 5761         1.213040
# 12974        1.216077
# 7542         1.238109
# ...               ...
# 399          1.305571
# 16225        1.273085
# 4567         1.151840
# 3141         1.229800
# 9427         1.321339
#
# [4087 rows x 16 columns]

# %%
x_test , y_test = train_data.drop(["median_house_value"],axis = 1),train_data["median_house_value"]

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3137     -117.65     35.00                36.0     7.077498        5.758902
# 6236     -117.96     34.06                34.0     7.708411        5.945421
# 8151     -118.10     33.81                36.0     7.013915        5.220356
# 3190     -119.80     36.29                 7.0     6.173786        4.442651
# 15315    -117.38     33.20                26.0     7.264030        5.958425
# ...          ...       ...                 ...          ...             ...
# 13517    -117.34     34.10                14.0     9.378225        7.802209
# 11520    -118.06     33.72                14.0     7.888335        5.805135
# 7165     -118.17     34.05                35.0     7.136483        5.686975
# 3635     -118.43     34.23                37.0     7.460490        5.913503
# 2622     -124.10     40.95                17.0     7.303843        5.846439
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 3137     6.511745    5.488938         1.9107      False    True   False
# 6236     7.289611    5.902633         4.4102       True   False   False
# 8151     6.098074    5.181784         3.7031       True   False   False
# 3190     5.793014    4.644391         5.1728      False    True   False
# 15315    6.882437    5.762051         1.3903      False   False   False
# ...           ...         ...            ...        ...     ...     ...
# 13517    8.801018    7.740664         2.4878      False    True   False
# 11520    6.872128    5.768321        15.0001      False   False   False
# 7165     8.003363    5.713733         3.1528       True   False   False
# 3635     6.967909    5.877736         3.9615       True   False   False
# 2622     6.714171    5.758902         1.8993      False   False   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_room
# 3137      False       False       0.813692        1.289411
# 6236      False       False       0.771290        1.305927
# 8151      False       False       0.744286        1.353572
# 3190      False       False       0.719599        1.329299
# 15315     False        True       0.820264        1.260667
# ...         ...         ...            ...             ...
# 13517     False       False       0.831949        1.211553
# 11520     False        True       0.735914        1.367527
# 7165      False       False       0.796888        1.249005
# 3635      False       False       0.792643        1.269280
# 2622      False        True       0.800461        1.268270
#
# [16346 rows x 15 columns]

# %%
x_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3137     -117.65     35.00                36.0     7.077498        5.758902
# 6236     -117.96     34.06                34.0     7.708411        5.945421
# 8151     -118.10     33.81                36.0     7.013915        5.220356
# 3190     -119.80     36.29                 7.0     6.173786        4.442651
# 15315    -117.38     33.20                26.0     7.264030        5.958425
# ...          ...       ...                 ...          ...             ...
# 13517    -117.34     34.10                14.0     9.378225        7.802209
# 11520    -118.06     33.72                14.0     7.888335        5.805135
# 7165     -118.17     34.05                35.0     7.136483        5.686975
# 3635     -118.43     34.23                37.0     7.460490        5.913503
# 2622     -124.10     40.95                17.0     7.303843        5.846439
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 3137     6.511745    5.488938         1.9107      False    True   False
# 6236     7.289611    5.902633         4.4102       True   False   False
# 8151     6.098074    5.181784         3.7031       True   False   False
# 3190     5.793014    4.644391         5.1728      False    True   False
# 15315    6.882437    5.762051         1.3903      False   False   False
# ...           ...         ...            ...        ...     ...     ...
# 13517    8.801018    7.740664         2.4878      False    True   False
# 11520    6.872128    5.768321        15.0001      False   False   False
# 7165     8.003363    5.713733         3.1528       True   False   False
# 3635     6.967909    5.877736         3.9615       True   False   False
# 2622     6.714171    5.758902         1.8993      False   False   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_room
# 3137      False       False       0.813692        1.289411
# 6236      False       False       0.771290        1.305927
# 8151      False       False       0.744286        1.353572
# 3190      False       False       0.719599        1.329299
# 15315     False        True       0.820264        1.260667
# ...         ...         ...            ...             ...
# 13517     False       False       0.831949        1.211553
# 11520     False        True       0.735914        1.367527
# 7165      False       False       0.796888        1.249005
# 3635      False       False       0.792643        1.269280
# 2622      False        True       0.800461        1.268270
#
# [16346 rows x 15 columns]

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# 0.6728351283591505

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest = RandomForestRegressor()

forest.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test,y_test)
# Out:
# 0.9745524040199267
